# %% [markdown]
# <a href="https://colab.research.google.com/github/UmbertoFasci/HFP_Analysis/blob/main/InitialAnalysisHFP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis of Human Footprint Raster Data
# How do certain ranges of human footprint data influence the distribution of Batrachochitrium dendrobatidis

# %%
# Important library for many geopython libraries
# !apt install gdal-bin python-gdal python3-gdal 
# Install rtree - Geopandas requirment
# !apt install python3-rtree 
# Install Geopandas
# !pip install git+git://github.com/geopandas/geopandas.git
# Install Rasterio
# !pip install rasterio
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gdal-bin is already the newest version (2.2.3+dfsg-2).
# python-gdal is already the newest version (2.2.3+dfsg-2).
# python3-gdal is already the newest version (2.2.3+dfsg-2).
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
#   cuda-cuobjdump-11-0 cuda-cupti-10-0 cuda-cupti-10-1 cuda-cupti-11-0
#   cuda-cupti-dev-11-0 cuda-documentation-10-0 cuda-documentation-10-1
#   cuda-documentation-11-0 cuda-documentation-11-1 cuda-gdb-10-0 cuda-gdb-10-1
#   cuda-gdb-11-0 cuda-gpu-library-advisor-10-0 cuda-gpu-library-advisor-10-1
#   cuda-libraries-10-0 cuda-libraries-10-1 cuda-libraries-11-0
#   cuda-memcheck-10-0 cuda-memcheck-10-1 cuda-memcheck-11-0 cuda-nsight-10-0
# ...

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import rasterio

# %%
human_influence = rasterio.open('human_influence2.asc')

# %%
print(f"Width: {human_influence.width}")
print(f"Height: {human_influence.height}")
# Out:
# Width: 5561
# Height: 5509

# %%
print(f"Human Influence Data Indexes: {human_influence.indexes}")
# Out:
# Human Influence Data Indexes: (1,)

# %%
print(f"Human Influence Data Band1: {human_influence.read(1)}")
# Out:
# Human Influence Data Band1: [[-9999 -9999 -9999 ... -9999 -9999 -9999]
#  [-9999 -9999 -9999 ... -9999 -9999 -9999]
#  [-9999 -9999 -9999 ... -9999 -9999 -9999]
#  ...
#  [-9999 -9999 -9999 ... -9999 -9999 -9999]
#  [-9999 -9999 -9999 ... -9999 -9999 -9999]
#  [-9999 -9999 -9999 ... -9999 -9999 -9999]]

# %%
from rasterio.plot import show
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, figsize=(15, 18))
show((human_influence), cmap='nipy_spectral')
plt.show()
